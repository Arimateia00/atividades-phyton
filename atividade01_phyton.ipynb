# %% [markdown]
# <a href="https://colab.research.google.com/github/Arimateia00/atividades-phyton/blob/main/atividade01_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade01-Introdução ao Phyton

# %%
print ("Olá mundo!")
print ("Curso Técnico em Informática")
# Out:
# Olá mundo!
# Curso Técnico em Informática

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input ("Digite o conteúdo estudado: ")
atividade = input ("Digite o número da atividade: ")
print ("\n---Informações da atividade ---")
print ("Disciplina:",disciplina)
print("Conteúdo:", conteudo)
print ("Atividade:", atividade)
# Out:
# Digite o nome da disciplina: Algoritmo e lógica de Progamação
# Digite o conteúdo estudado: Phyton
# Digite o número da atividade: 01
#
# ---Informações da atividade ---
# Disciplina: Algoritmo e lógica de Progamação
# Conteúdo: Phyton
# Atividade: 01

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print ("Resultado:",soma)
# Out:
# Resultado 30
